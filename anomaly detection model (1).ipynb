# %% [markdown]
# ### Anomaly Detection in IoT sensors

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib.pyplot import axes, title
import numpy as np

# %%
#reading csv files
df0 = pd.read_csv("data_tunis.csv")

# %%
df0.head()
# Out:
#          date  Tmin  Tmax  vent  pluie
# 0  01/01/2010  12.0  19.0  50.0    0.0
# 1  02/01/2010  12.0  17.0  35.0    2.7
# 2  03/01/2010  11.0  18.0  15.0    0.5
# 3  04/01/2010   9.0  19.0  13.0    0.0
# 4  05/01/2010   8.0  23.0  16.0    0.0

# %%
# Fill some null values
df0 = df0.bfill(axis=0)

# Remove null acquisations
df0 = df0.dropna()

# Replace min_temp and max_temp with avg_temp
df0['temp'] = (df0['Tmin'] + df0['Tmax']) / 2
df0 = df0.drop('Tmin',axis=1)
df0 = df0.drop('Tmax',axis=1)

df0
# Out:
#             date  vent  pluie  temp
# 0     01/01/2010  50.0    0.0  15.5
# 1     02/01/2010  35.0    2.7  14.5
# 2     03/01/2010  15.0    0.5  14.5
# 3     04/01/2010  13.0    0.0  14.0
# 4     05/01/2010  16.0    0.0  15.5
# ...          ...   ...    ...   ...
# 2915  25/12/2017  15.0    0.2   8.0
# 2916  26/12/2017  29.0    0.0  11.5
# 2917  27/12/2017  29.0    0.0   6.0
# 2918  28/12/2017  28.0    3.5  11.0
# 2919  29/12/2017  39.0    6.3  12.5
#
# [2920 rows x 4 columns]

# %%
import pandas as pd

# Create empty dataframes for each month
df_jan = pd.DataFrame(columns=df0.columns)
df_feb = pd.DataFrame(columns=df0.columns)
df_mar = pd.DataFrame(columns=df0.columns)
df_apr = pd.DataFrame(columns=df0.columns)
df_may = pd.DataFrame(columns=df0.columns)
df_jun = pd.DataFrame(columns=df0.columns)
df_jul = pd.DataFrame(columns=df0.columns)
df_aug = pd.DataFrame(columns=df0.columns)
df_sep = pd.DataFrame(columns=df0.columns)
df_oct = pd.DataFrame(columns=df0.columns)
df_nov = pd.DataFrame(columns=df0.columns)
df_dec = pd.DataFrame(columns=df0.columns)

# Fill the dataframes of each month
for i in range(len(df0)):
    if df0.loc[i]['date'][3:5] == '01':
        df_jan = pd.concat([df_jan, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '02':
        df_feb = pd.concat([df_feb, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '03':
        df_mar = pd.concat([df_mar, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '04':
        df_apr = pd.concat([df_apr, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '05':
        df_may = pd.concat([df_may, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '06':
        df_jun = pd.concat([df_jun, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '07':
        df_jul = pd.concat([df_jul, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '08':
        df_aug = pd.concat([df_aug, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '09':
        df_sep = pd.concat([df_sep, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '10':
        df_oct = pd.concat([df_oct, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '11':
        df_nov = pd.concat([df_nov, df0.loc[[i]]], ignore_index=True)
    if df0.loc[i]['date'][3:5] == '12':
        df_dec = pd.concat([df_dec, df0.loc[[i]]], ignore_index=True)
# Out:
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_jan = pd.concat([df_jan, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_feb = pd.concat([df_feb, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_mar = pd.concat([df_mar, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:26: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_apr = pd.concat([df_apr, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:28: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_may = pd.concat([df_may, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_jun = pd.concat([df_jun, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:32: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_jul = pd.concat([df_jul, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:34: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_aug = pd.concat([df_aug, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_sep = pd.concat([df_sep, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_oct = pd.concat([df_oct, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_nov = pd.concat([df_nov, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\3666398368.py:42: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_dec = pd.concat([df_dec, df0.loc[[i]]], ignore_index=True)
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_sep = df_sep.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_jan = df_jan.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_feb = df_feb.append(df0.loc[i])
# ...
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:36: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_oct = df_oct.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:38: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_nov = df_nov.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_23676\4269858596.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_dec = df_dec.append(df0.loc[i])

# %%
# Choose a month to work with; for example: January
df_curr = df_jan

# Remove the columns 'date' and 'index'
df_curr = df_curr.reset_index().drop(['date', 'index'], axis=1)

# Get xdata, ydata, and zdata for 3D plot
xdata = df_curr['vent']
ydata = df_curr['pluie']
zdata = df_curr['temp']

# Define thresholds
MAX_PLUIE = 20  
MAX_VENT = 60
MAX_TEMP = 30
MIN_TEMP = 6

# Initialize the anomaly reference DataFrame
df_anomaly_reference = pd.DataFrame(columns=df_curr.columns)

# Fill the DataFrame of reference points
df_anomaly_reference = df_curr[
    (df_curr['pluie'] > MAX_PLUIE) |
    (df_curr['vent'] > MAX_VENT) |
    (df_curr['temp'] > MAX_TEMP) |
    (df_curr['temp'] < MIN_TEMP)
]

# Print the number of anomalies
print("The number of anomaly reference points is:", len(df_anomaly_reference))
# Out:
# The number of anomaly reference points is: 6

# %% [markdown]
#  ### 1st algorithm: DBSCAN

# %%
import time
import tracemalloc

from sklearn.cluster import DBSCAN
from sklearn.preprocessing import MinMaxScaler

start_time = time.time()
tracemalloc.start()

scaler = MinMaxScaler()
num2 = scaler.fit_transform(df_curr)
num2 = pd.DataFrame(num2, columns=df_curr.columns)

scaler = MinMaxScaler() 
outlier_detection = DBSCAN(eps = .2, metric="euclidean", min_samples = 5, n_jobs = -1)
num2 = scaler.fit_transform(df_curr)
num2 = pd.DataFrame(num2, columns = df_curr.columns)
clusters = outlier_detection.fit_predict(num2)

# 2D Plot: pluie = f(vent)
from matplotlib import cm
cmap = cm.get_cmap('Set1')
df_curr.plot.scatter(x='vent',y='pluie', c=clusters, cmap=cmap, colorbar = False)

# 2D Plot: pluie = f(temp)
from matplotlib import cm
cmap = cm.get_cmap('Set1')
df_curr.plot.scatter(x='temp',y='pluie', c=clusters, cmap=cmap, colorbar = False)

current, peak = tracemalloc.get_traced_memory()
end_time = time.time()
print(f"Execution time: {end_time - start_time:.2f} seconds")
print(f"Current memory usage: {current / 10**6:.2f} MB")
print(f"Peak memory usage: {peak / 10**6:.2f} MB")

# Stop tracemalloc
tracemalloc.stop()
# PS: This will be the only time that we show 2D plots
# Out:
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\417063171.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Set1')
# C:\Users\SRISHTI\AppData\Local\Temp\ipykernel_14736\417063171.py:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('Set1')
# Execution time: 1.08 seconds
# Current memory usage: 2.06 MB
# Peak memory usage: 2.09 MB

# %%
# 3D Plot: pluie = f(temp, vent)
ax = axes(projection='3d')
ax.scatter3D(xdata, ydata, zdata, c=clusters, cmap=cmap)
ax.set_xlabel('vent',fontsize=20)
ax.set_ylabel('pluie',fontsize=20)
ax.set_zlabel('temp',fontsize=20)
title('DBSCAN — Anomalies')

true_predicted = 0
mistakes = 0

# Get True Negative and False Positive 
for i in range(len(clusters)):
    if clusters[i] == -1 and i in df_anomaly_reference.index:
        true_predicted += 1
    if clusters[i] == -1 and i not in df_anomaly_reference.index:
        mistakes += 1

print("DBSCAN  | True Negative = " + str(true_predicted))
print("DBSCAN  | False Positive = " + str(mistakes))
# Out:
# DBSCAN  | True Negative = 1
# DBSCAN  | False Positive = 0

# %% [markdown]
# ### 2nd algorithm: Isolation Forests

# %%
import time
import tracemalloc
from sklearn.ensemble import IsolationForest
start_time = time.time()
tracemalloc.start()
rs=np.random.RandomState(0)
clf = IsolationForest(max_samples=100,random_state=rs, contamination=.01) 
clf.fit(df_curr)
if_scores = clf.decision_function(df_curr)
if_anomalies=clf.predict(df_curr)
if_anomalies=pd.Series(if_anomalies).replace([-1,1],[1,0])
if_anomalies=df_curr[if_anomalies==1]

# 3D Plot
ax = plt.axes(projection='3d')
ax.scatter3D(xdata, ydata, zdata, c='white',s=20,edgecolor='k')
ax.scatter3D(if_anomalies['vent'], if_anomalies['pluie'], if_anomalies['temp'], c='red')
ax.set_xlabel('vent',fontsize=20)
ax.set_ylabel('pluie',fontsize=20)
ax.set_zlabel('temp',fontsize=20)
plt.title('Isolation Forests — Anomalies')

true_predicted = 0
mistakes = 0

# Get True Negative and False Positive 
for i in range(len(clusters)):
    if i in if_anomalies.index and i in df_anomaly_reference.index:
        true_predicted += 1
    if i in if_anomalies.index and i not in df_anomaly_reference.index:
        mistakes += 1

print("Isolation Forests | True Negative = " + str(true_predicted))
print("Isolation Forests | False Positive = " + str(mistakes))
current, peak = tracemalloc.get_traced_memory()
end_time = time.time()
print(f"Execution time: {end_time - start_time:.2f} seconds")
print(f"Current memory usage: {current / 10**6:.2f} MB")
print(f"Peak memory usage: {peak / 10**6:.2f} MB")

# Stop tracemalloc
tracemalloc.stop()
# PS: This will be the only time that we show 2D plots
# Out:
# Isolation Forests | True Negative = 3
# Isolation Forests | False Positive = 0
# Execution time: 6.32 seconds
# Current memory usage: 0.80 MB
# Peak memory usage: 0.82 MB

# %% [markdown]
# ### 3rd algorithm: Local Outlier Factor

# %%
import time
import tracemalloc
from sklearn.neighbors import LocalOutlierFactor
start_time = time.time()
tracemalloc.start()
clf = LocalOutlierFactor(n_neighbors=30, contamination=.01)
y_pred = clf.fit_predict(df_curr)
LOF_Scores = clf.negative_outlier_factor_
LOF_pred=pd.Series(y_pred).replace([-1,1],[1,0])
LOF_anomalies=df_curr[LOF_pred==1]

# 3D Plot
ax = plt.axes(projection='3d')
ax.scatter3D(xdata, ydata, zdata, c='white',s=20,edgecolor='k')
ax.scatter3D(LOF_anomalies['vent'], LOF_anomalies['pluie'], LOF_anomalies['temp'], c='red')
ax.set_xlabel('vent',fontsize=20)
ax.set_ylabel('pluie',fontsize=20)
ax.set_zlabel('temp',fontsize=20)
plt.title('Local Outlier Factor — Anomalies')

true_predicted = 0
mistakes = 0

# Get True Negative and False Positive 
for i in range(len(clusters)):
    if i in LOF_anomalies.index and i in df_anomaly_reference.index:
        true_predicted += 1
    if i in LOF_anomalies.index and i not in df_anomaly_reference.index:
        mistakes += 1

print("Local Outlier Factor | True Negative = " + str(true_predicted))
print("Local Outlier Factor | False Positive = " + str(mistakes))
current, peak = tracemalloc.get_traced_memory()
end_time = time.time()
print(f"Execution time: {end_time - start_time:.2f} seconds")
print(f"Current memory usage: {current / 10**6:.2f} MB")
print(f"Peak memory usage: {peak / 10**6:.2f} MB")

# Stop tracemalloc
tracemalloc.stop()
# PS: This will be the only time that we show 2D plots
# Out:
# Local Outlier Factor | True Negative = 3
# Local Outlier Factor | False Positive = 0
# Execution time: 0.26 seconds
# Current memory usage: 0.66 MB
# Peak memory usage: 0.69 MB

# %% [markdown]
# ### 4th algorithm: One-Class Support Vector Machines

# %%
import time
import tracemalloc
from sklearn import svm
start_time = time.time()
tracemalloc.start()
clf=svm.OneClassSVM(nu=.02,kernel='rbf',gamma=.005)
clf.fit(df_curr)
y_pred=clf.predict(df_curr)

# 3D Plot
ax = plt.axes(projection='3d')
ax.scatter3D(xdata, ydata, zdata, c=y_pred, cmap=cmap)
ax.set_xlabel('vent',fontsize=20)
ax.set_ylabel('pluie',fontsize=20)
ax.set_zlabel('temp',fontsize=20)
plt.title('One-Class Support Vector Machines — Anomalies')

true_predicted = 0
mistakes = 0

# Get True Negative and False Positive 
for i in range(len(clusters)):
    if y_pred[i] == -1 and i in df_anomaly_reference.index:
        true_predicted += 1
    if y_pred[i] == -1 and i not in df_anomaly_reference.index:
        mistakes += 1

print("One-Class Support Vector Machines | True Negative = " + str(true_predicted))
print("One-Class Support Vector Machines | False Positive = " + str(mistakes))
current, peak = tracemalloc.get_traced_memory()
end_time = time.time()
print(f"Execution time: {end_time - start_time:.2f} seconds")
print(f"Current memory usage: {current / 10**6:.2f} MB")
print(f"Peak memory usage: {peak / 10**6:.2f} MB")

# Stop tracemalloc
tracemalloc.stop()
# PS: This will be the only time that we show 2D plots
# Out:
# One-Class Support Vector Machines | True Negative = 3
# One-Class Support Vector Machines | False Positive = 6
# Execution time: 0.19 seconds
# Current memory usage: 2.88 MB
# Peak memory usage: 2.91 MB
